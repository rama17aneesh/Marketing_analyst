# %% [markdown]
# # The scope of the project
#
# ### Step 1:-  Problem understanding
# - You're a marketing analyst and you've been told by the Chief Marketing Officer that recent marketing campaigns have not been as effective as they were expected to be. You need to analyze the data set to understand this problem and propose data-driven solutions.
#
# ### Step 2:- Goal
#
# - You're a marketing analyst and you've been told by the Chief Marketing Officer that recent marketing campaigns have not been as effective as they were expected to be. You need to analyze the data set to understand this problem and propose data-driven solutions.
# - This notebook contains an analysis on some marketing data. The goal for this project was to do the following:
#
# 1. Get acquainted with the data
# 2. Clean the data so it is ready for analysis
# 3. Develop some questions for analysis
# 4. Analyze variables within the data to gain patterns and insights on these questions
#
# ### Step 3:- Data
#
# - The data for this project was downloaded from Kaggle:
#
#    https://www.kaggle.com/jackdaoud/marketing-data
#
# Information regarding the features for the data are located in the Column section on the website.
#
# Note:- always find a dataset that is there with data dictionary.
# ### Step 4 :-  Data & Statistical Analysis
#
# Recent marketing campaigns have not been as effective as they were expected to be.
# - Q1. Do customers buy products based on their income or based on the age group?
# - Q2. Do customers purchase products through online store or store purchase?
# - Q3. what and where to market our deals, so that customers visit store or online?
#
# The following independent variables will be focused on in the analysis:
#
# - income
# - complain and response
# - age.
#
#
# - The goal will be to see how these independent variables associate with the following dependent variables:
#
# . mnt_wines
# . mnt_fruits
# . mnt_meat_products
# . mnt_fish_products
# . mnt_sweet_products
# . mnt_gold_products
# . num_deals_purchases
# . num_web_purchases
# . num_catalog_purchases
# . num_store_purchases
#
# ### Step 5 :- Evaluation
#
# - The information we generate from our Analysis will be helpful for a marketing department, strategies could be used to increase customers for the store.

# %% [markdown]
# ## Import python Modules

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import re

# %% [markdown]
# ## Loading the Data
#
# - `marketing_data.csv` are read in as `DataFrame` called `marketing_data`
# -  The DataFrame is glimpsed with `.head()` to check its contents.
# -  `marketing_data.info` to show concise summary of the DataFrame.

# %%
marketing_data = pd.read_csv("marketing_data.csv")
marketing_data.head(15)
# Out:
#        id  YearBirth   Education MaritalStatus       Income  Kidhome  \
# 0    1826       1970  Graduation      Divorced  $84,835.00         0
# 1       1       1961  Graduation        Single  $57,091.00         0
# 2   10476       1958  Graduation       Married  $67,267.00         0
# 3    1386       1967  Graduation      Together  $32,474.00         1
# 4    5371       1989  Graduation        Single  $21,474.00         1
# 5    7348       1958         PhD        Single  $71,691.00         0
# 6    4073       1954    2n Cycle       Married  $63,564.00         0
# 7    1991       1967  Graduation      Together  $44,931.00         0
# 8    4047       1954         PhD       Married  $65,324.00         0
# 9    9477       1954         PhD       Married  $65,324.00         0
# 10   2079       1947    2n Cycle       Married  $81,044.00         0
# 11   5642       1979      Master      Together  $62,499.00         1
# 12  10530       1959         PhD         Widow  $67,786.00         0
# ...

# %%
marketing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2240 non-null   int64
#  1   YearBirth            2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   MaritalStatus        2240 non-null   object
#  4   Income               2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   DtCustomer           2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProducts      2240 non-null   int64
# ...

# %% [markdown]
# - see what columns have missing data
# - Income has missing value

# %%
marketing_data.isnull().sum()
# Out:
# id                      0
# YearBirth               0
# Education               0
# MaritalStatus           0
# Income                 24
# Kidhome                 0
# Teenhome                0
# DtCustomer              0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProducts         0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %% [markdown]
#   - describe() method,  generates descriptive statistics of numeric columns in a  dataframe, provides shape of a datsets's distribution excluding 'NaN' values.

# %%
print(marketing_data.describe())
# Out:
#                  id    YearBirth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %% [markdown]
# ## Analysis
# #### Data Cleaning and feature engineering
# - `Income` variable is one of the main variables that will explored in the analysis, so it is essential that it is tidy and ready for exploration.
# - `Income` has `dollar sign($)`, i will take out the `$` Change `Income value` to float and replace the missing values of income with the mean income using `.mean()` method.
# - But, before applying `.mean()` and cleaning the data, i want to check for the rows having `Null values`so i will be able to take decision whether to give `.mean' or drop` the rows
# - Lets do some `Feature Engineering` to get `Age` that can be derived from `Year_Birth` and `Age_Group` from `Age`.
#
# - If no income value is found, the `re.sub` operation will raise an error. To handle this, you can check if income is empty before applying `re.sub`.

# %% [markdown]
# - its with this block of code i was getting type error : can only concatenate str to str.
# - i am returning `None` if there are `NaN` values, while i apply mean  to the income column to replace the `NaN` values, the function is identifying str(None) that is why it is not able to fill with mean.

# %% [markdown]
# - By analyzing the data where `Income` is `NaN`, it wouldn't make any sense to drop the rows of data cause by looking at the data they seem to be potential customers for stores business and from different countries will ikely effect the analysis later on when we are comparing countries.
# - i will replace the `Nan` value with the `.mean`.
#
# - Reolved the issue without using `re` modeule and not using `if-else` statement because it returned `NaN` values as `None` when it came to filling the `NaN` values with the `mean` it gave me a `Type Error` can only concatenate  str to str. then i refered to `pandas` module using `replace` method to remove `$ and comma(,)` and converted string to numeric variable beacuse `.mean()` can only change numeric values including float values. then calculating mean and lastly using `fillna()` method to replace the `NaN` values with mean.

# %%
marketing_data['Income'] = marketing_data['Income'].replace('[\$,]', '', regex=True).astype(float)

# %%
marketing_data.isnull().sum()
# Out:
# id                      0
# YearBirth               0
# Education               0
# MaritalStatus           0
# Income                 24
# Kidhome                 0
# Teenhome                0
# DtCustomer              0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProducts         0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %% [markdown]
# - I will remove the outliers.

# %%
sns.boxplot(x=marketing_data["Income"])
# Out:
# <Axes: xlabel='Income'>

# %%
marketing_data = marketing_data[marketing_data['Income']<300000]

sns.boxplot(x = marketing_data['Income'])
# Out:
# <Axes: xlabel='Income'>

# %%
marketing_data['Income'].describe()
# Out:
# count      2215.000000
# mean      51969.861400
# std       21526.320095
# min        1730.000000
# 25%       35284.000000
# 50%       51373.000000
# 75%       68487.000000
# max      162397.000000
# Name: Income, dtype: float64

# %% [markdown]
# ####  To facilitate easier analysis, the marketing_data DataFrame was modified as follows:
#
# - A new column named `Age` was created by subtracting each value in the `YearBirth` column from 2021, the year the dataset is from.
# - - downsides of adding new column
# 1. missing values - there are no missing values in `YearBirth` feature.
# - just to count number of outliers and figure out whther to be removed or not is the purpose. IT can effect the performance but for my project analysis, I am very keen to solve this question.

# %%
marketing_data['Age'] = 2024 - marketing_data['YearBirth']

# %%
marketing_data['Age'].describe()
# Out:
# count    2215.000000
# mean       55.183296
# std        11.987000
# min        28.000000
# 25%        47.000000
# 50%        54.000000
# 75%        65.000000
# max       131.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(x = marketing_data['Age'])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# - Now we have to group `Age` to ease our analysis.
# - a new column called age_group has been added to the marketing_data DataFrame. This column categorizes ages into the following groups:
#
# -- 18 to 35
# -- 36 to 50
# -- 51 to 85
# -- 86 and older

# %%
def age_groups(Age):
    if 18 <= Age <= 35 : 
        return '18 to 35' 
    elif 35 < Age <= 50 : 
        return '36 to 50'
    elif 50 < Age <= 85 : 
        return '51 to 85'
    else : 
        return '86 and Older'

# %%
marketing_data['age_group']= marketing_data['Age'].apply(age_groups)

# %%
print(marketing_data)
# Out:
#          id  YearBirth   Education MaritalStatus   Income  Kidhome  Teenhome  \
# 0      1826       1970  Graduation      Divorced  84835.0        0         0
# 1         1       1961  Graduation        Single  57091.0        0         0
# 2     10476       1958  Graduation       Married  67267.0        0         1
# 3      1386       1967  Graduation      Together  32474.0        1         1
# 4      5371       1989  Graduation        Single  21474.0        1         0
# ...     ...        ...         ...           ...      ...      ...       ...
# 2235  10142       1976         PhD      Divorced  66476.0        0         1
# 2236   5263       1977    2n Cycle       Married  31056.0        1         0
# 2237     22       1976  Graduation      Divorced  46310.0        1         0
# 2238    528       1978  Graduation       Married  65819.0        0         0
# 2239   4070       1969         PhD       Married  94871.0        0         2
#
# ...

# %% [markdown]
# - The highest count of customers shopping are from the age `Secound_highest =36 to 50` and `First_highest = 51 to 85`. now letss see in EDA whether they are shopping from in-store or online store and what are they buying the most also lets check age group of `18 to 35` what products do they purchase in-store or online and attract them from the deals to see if they benefit from marketing campaigns.

# %%
sns.countplot(x= marketing_data['age_group'],order = ['18 to 35', '36 to 50','51 to 85', '86 and older'])
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %% [markdown]
# ### Analysis
#
# 1. With the data cleaned and prepared, we can begin our exploratory data analysis. The independent variables we'll examine are:
# - Income
# - age
# - customers complaints( there is no variable for rectified complaint), there is response of before marketing campaigns.
# - The goal will be to see how these independent variables(Income and Age) associated with the following dependent variable

# %% [markdown]
# - r = 0.6304, p = 0: income and num_of_store purchses, a strongly moderate positive and significant linear correlation.
# - r = 0.4588, p = 0: income and num_of_webpurchases, a moderate positive and significant line=ar correlation.
# - r = 0.6965, p = 0: income and num_of_catalogpurchases, a strong positive and significant linear correlation.
#
# - These values provide a good indication of the relationship between `Income and NUM_of_webpurchases,Num_of_storepurchases,Num_of_catalogpurchases` respectively. Relationship between the variables is highly unlikely to occur by chance and also we need to check for outliers but in this data I have only considered values cleared the outliers from the frame.
#
# - by this relationship, i can assume that as majority of customers are from the `age_group of 86 and older`, they might not be accessing the webStore to purchase goods and by reading newspapers or getting catalogs by mailing services if we tend to increase more catalogs with the increased amount of deals it could probably increase in bring more customers for goods purchases.
#
# - So the target is to focus on younger age group, so we need to tailor the website online marketing strategies. Make the website more accessible and appealing to older age_group `86 and older` to recommend to visit and self-visit the website.
#
# - As there is no NUmofStoreVisits lets concentrate on NUmofWebVisits. we can check for numberofWebVisits and NumofWebProductPurchased item and there happened to be no information on that the question left unanswered.

# %%
from scipy import stats
variables = ['Income', 'NumStorePurchases', 'NumCatalogPurchases', 'NumWebPurchases']

# Calculate the correlation matrix
correlation_matrix = marketing_data[variables].corr()

# Print the correlation matrix                                                     
print("Correlation Matrix:")
print(correlation_matrix)
# Perform pairwise correlation tests
for var in ['NumStorePurchases', 'NumCatalogPurchases', 'NumWebPurchases']:
    r, p = stats.pearsonr(marketing_data['Income'], marketing_data[var])
    print(f"\nPearson correlation between Income and {var}:")
    print(f"r = {r:.4f}")
    print(f"p-value = {p:.4f}")

# Visualize the correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap: Income vs. Purchase Types')
plt.show()

# Scatter plots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
for i, var in enumerate(['NumStorePurchases', 'NumCatalogPurchases', 'NumWebPurchases']):
    sns.scatterplot(data=marketing_data, x='Income', y=var, ax=axes[i])
    axes[i].set_title(f'Income vs {var}')
plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix:
#                        Income  NumStorePurchases  NumCatalogPurchases  \
# Income               1.000000           0.630397             0.696541
# NumStorePurchases    0.630397           1.000000             0.517743
# NumCatalogPurchases  0.696541           0.517743             1.000000
# NumWebPurchases      0.458812           0.516191             0.386808
#
#                      NumWebPurchases
# Income                      0.458812
# NumStorePurchases           0.516191
# NumCatalogPurchases         0.386808
# NumWebPurchases             1.000000
#
# Pearson correlation between Income and NumStorePurchases:
# r = 0.6304
# p-value = 0.0000
#
# Pearson correlation between Income and NumCatalogPurchases:
# r = 0.6965
# p-value = 0.0000
#
# Pearson correlation between Income and NumWebPurchases:
# r = 0.4588
# p-value = 0.0000

# %%
# to understand this plot better i need to know the income range by that i can asuume how to increase the deal products.
products_list = ["MntWines", "MntFruits", "MntMeatProducts", "MntFishProducts", "MntSweetProducts", "MntGoldProducts"]
#visualize products purchased with income
fig = plt.figure(figsize=(9,10))                                    
# looping through the length of the amounts columns list
plot = 0
for i in range(len(products_list)):
    plot += 1
    # setting up the subplots
    ax = plt.subplot(3, 2, plot)
    # plotting amounts purchased vs. income
    sns.scatterplot(y= marketing_data[products_list[i]], x=marketing_data["Income"])
    plt.title("Purchasing Behavior by Income")
plt.tight_layout()
plt.show()

# %% [markdown]
# - `also we need to check for num_of_webvisits and by which age_group it has more association with helps us to gain more knowledge and can give an affirmative decision.`

# %% [markdown]
# - from this, we have to intrepret correctly as they are on an average more web visits by `36 to 50 and 51 to 85` than `18 to 35`. also lets check for store_visits oh shit! it seems the data has no store_visits i have to stop my analysis over here and can give more generalized opinion.

# %%
# Calculate average NumWebVisitsMonth for each age group
age_group_visits = marketing_data.groupby('age_group')['NumWebVisitsMonth'].mean().reset_index()

# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='age_group', y='NumWebVisitsMonth', data=age_group_visits)
plt.title('Average Number of Web Visits per Month by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Average Number of Web Visits per Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Print the results
print(age_group_visits)

# Calculate overall statistics
overall_mean = marketing_data['NumWebVisitsMonth'].mean()
overall_median = marketing_data['NumWebVisitsMonth'].median()
overall_std = marketing_data['NumWebVisitsMonth'].std()

print(f"\nOverall Statistics:")
print(f"Mean: {overall_mean:.2f}")
print(f"Median: {overall_median:.2f}")
print(f"Standard Deviation: {overall_std:.2f}")
# Out:
#       age_group  NumWebVisitsMonth
# 0      18 to 35           4.966667
# 1      36 to 50           5.613333
# 2      51 to 85           5.185131
# 3  86 and Older           3.333333
#
# Overall Statistics:
# Mean: 5.32
# Median: 6.00
# Standard Deviation: 2.43
